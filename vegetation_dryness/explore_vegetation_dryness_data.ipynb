# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("input_data.csv")
del data['Unnamed: 0']
data['date'] = pd.to_datetime(data['date']).dt.year

# %%
data.describe()
# Out:
#         percent(t)         date     slope(t)  elevation(t)  canopy_height(t)  \
# count  2615.000000  2615.000000  2615.000000   2615.000000       2615.000000
# mean    104.217605  2016.860803     2.461754   1180.127342         15.021033
# std      39.522718     1.017320     2.164092    794.544996          9.870505
# min      16.000000  2015.000000     0.099110     37.000000          0.000000
# 25%      75.500000  2016.000000     0.815488    451.000000          7.000000
# 50%      96.000000  2017.000000     1.899994   1067.000000         17.000000
# 75%     121.500000  2018.000000     3.095040   1756.000000         23.000000
# max     319.200000  2019.000000    10.661663   3159.000000         36.000000
#
#        forest_cover(t)      silt(t)      sand(t)      clay(t)      vv(t-3)  \
# count      2615.000000  2615.000000  2615.000000  2615.000000  2615.000000
# mean         83.546463    13.724665    25.221415     2.486807   -10.286388
# ...

# %%
data.date.value_counts()
# Out:
# 2017    864
# 2018    809
# 2016    607
# 2015    309
# 2019     26
# Name: date, dtype: int64

# %%
for i in zip(data.site.value_counts(), data.site.unique()):
    print(i)
# Out:
# (36, 'Blackstone')
# (36, 'Hammett')
# (36, 'Kuna')
# (35, 'Simco')
# (35, 'Wild West')
# (34, 'Curlew')
# (33, 'Double Springs')
# (33, 'Dubois')
# (33, 'Idaho Falls')
# (32, 'Morgan Creek')
# (32, 'Pocatello')
# (31, 'Rock Spring')
# (31, 'Sand Creek Desert')
# (31, 'Sellers Creek')
# (31, 'Spar Canyon')
# (30, 'Table Legs Butte')
# (30, 'Sunset Heights')
# (30, 'Balanced Rock')
# (29, 'Notch Butte')
# (27, 'Ohio Gulch')
# (27, 'Rye Grass Flat')
# (27, 'Shoshone Basin')
# (27, 'Three Creek')
# (27, 'Three Island')
# (27, 'Black Cedar')
# (26, 'Big Indian')
# (26, 'Price Rec')
# (26, 'Muskrat')
# (26, 'Maple Canyon')
# (25, 'Squaw Peak')
# (25, 'Beus')
# (24, 'Snowbasin')
# (24, 'Lost Creek, WY')
# (24, 'RKO Road')
# (23, 'Fortynine C2A')
# (22, 'Cow Mountain')
# (22, 'Reader Ranch')
# (21, 'TahoeDonner')
# (21, 'Tyler Foote')
# (20, 'Corralitos New Growth')
# (20, 'Pulgas')
# (20, 'Saratoga Summit')
# (20, 'Blackberry Hill')
# (20, 'Clayton Ranch')
# (20, 'Weed Mill Site')
# ...

# %%
for i, j in zipdata.dtypes:
    print(i)
# Out:
# float64
# int64
# object
# float64
# int64
# int64
# int64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# ...

# %%
# percent = data['percent(t)'].to_numpy()
# del data['percent(t)']
del data['site']

# %%
d = data.to_numpy()

# %%
d.shape
# Out:
# (2615, 139)

# %%
train = data.loc[(data.date >= 2018)]

# %%
train
# Out:
#       slope(t)  elevation(t)  canopy_height(t)  forest_cover(t)  silt(t)  \
# 12    0.599961          1522                 0              130     36.0
# 13    0.599961          1522                 0              130     36.0
# 14    0.599961          1522                 0              130     36.0
# 15    0.599961          1522                 0              130     36.0
# 16    0.599961          1522                 0              130     36.0
# ...        ...           ...               ...              ...      ...
# 2603  0.979479          1479                 7              130     39.0
# 2604  0.979479          1479                 7              130     39.0
# 2605  0.979479          1479                 7              130     39.0
# 2606  0.979479          1479                 7              130     39.0
# 2607  0.979479          1479                 7              130     39.0
#
#       sand(t)  clay(t)    vv(t-3)    vh(t-3)  red(t-3)  ...  clay(t-2)  \
# ...

# %%
train.drop(['date', 'percent(t)'], axis=1, inplace=True)
# Out:
# C:\Users\sharan\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
train = train.to_numpy()

# %%
train.shape
# Out:
# (835, 138)
