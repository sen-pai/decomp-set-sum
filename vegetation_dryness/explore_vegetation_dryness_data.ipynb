# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("input_data.csv")
del data['Unnamed: 0']
data['date'] = pd.to_datetime(data['date']).dt.year

# %%
data.describe()
# Out:
#    percent(t)  date        site  slope(t)  elevation(t)  canopy_height(t)  \
# 0  132.666667  2015  Blackstone  0.599961          1522                 0
# 1   76.000000  2015  Blackstone  0.599961          1522                 0
# 2  140.000000  2016  Blackstone  0.599961          1522                 0
# 3   81.000000  2016  Blackstone  0.599961          1522                 0
# 4   52.000000  2016  Blackstone  0.599961          1522                 0
#
#    forest_cover(t)  silt(t)  sand(t)  clay(t)  ...  clay(t-2)  slope(t-1)  \
# 0              130     36.0     38.0     26.0  ...       26.0    0.599961
# 1              130     36.0     38.0     26.0  ...       26.0    0.599961
# 2              130     36.0     38.0     26.0  ...       26.0    0.599961
# 3              130     36.0     38.0     26.0  ...       26.0    0.599961
# 4              130     36.0     38.0     26.0  ...       26.0    0.599961
#
#    elevation(t-1)  canopy_height(t-1)  forest_cover(t-1)  silt(t-1)  \
# 0            1522                   0                130       36.0
# 1            1522                   0                130       36.0
# 2            1522                   0                130       36.0
# 3            1522                   0                130       36.0
# 4            1522                   0                130       36.0
#
#    sand(t-1)  clay(t-1)   latitude   longitude
# 0       38.0       26.0  42.441111 -115.885556
# 1       38.0       26.0  42.441111 -115.885556
# 2       38.0       26.0  42.441111 -115.885556
# 3       38.0       26.0  42.441111 -115.885556
# 4       38.0       26.0  42.441111 -115.885556
#
# [5 rows x 141 columns]

# %%
data.date.value_counts()
# Out:
# 2017    864
# 2018    809
# 2016    607
# 2015    309
# 2019     26
# Name: date, dtype: int64

# %%
for i in zip(data.site.value_counts(), data.site.unique()):
    print(i)
# Out:
# (36, 'Blackstone')
# (36, 'Hammett')
# (36, 'Kuna')
# (35, 'Simco')
# (35, 'Wild West')
# (34, 'Curlew')
# (33, 'Double Springs')
# (33, 'Dubois')
# (33, 'Idaho Falls')
# (32, 'Morgan Creek')
# (32, 'Pocatello')
# (31, 'Rock Spring')
# (31, 'Sand Creek Desert')
# (31, 'Sellers Creek')
# (31, 'Spar Canyon')
# (30, 'Table Legs Butte')
# (30, 'Sunset Heights')
# (30, 'Balanced Rock')
# (29, 'Notch Butte')
# (27, 'Ohio Gulch')
# (27, 'Rye Grass Flat')
# (27, 'Shoshone Basin')
# (27, 'Three Creek')
# (27, 'Three Island')
# (27, 'Black Cedar')
# (26, 'Big Indian')
# (26, 'Price Rec')
# (26, 'Muskrat')
# (26, 'Maple Canyon')
# (25, 'Squaw Peak')
# (25, 'Beus')
# (24, 'Snowbasin')
# (24, 'Lost Creek, WY')
# (24, 'RKO Road')
# (23, 'Fortynine C2A')
# (22, 'Cow Mountain')
# (22, 'Reader Ranch')
# (21, 'TahoeDonner')
# (21, 'Tyler Foote')
# (20, 'Corralitos New Growth')
# (20, 'Pulgas')
# (20, 'Saratoga Summit')
# (20, 'Blackberry Hill')
# (20, 'Clayton Ranch')
# (20, 'Weed Mill Site')
# (20, 'Juanita')
# (20, 'Oak Knoll')
# (20, 'Shinar Saddle')
# (20, 'Six Shooter')
# (19, 'Deer Hill')
# (18, 'Sugar Hill')
# (18, 'Quincy RD')
# (18, 'McCloud (SHF)')
# (18, 'Mad Ridge Fuel Break')
# (18, 'Mad River')
# (18, 'Ziegler')
# (18, 'Tally Lake North')
# (18, 'Deep Creek')
# (18, 'Benchmark')
# (17, 'Sylvan')
# (17, 'Tumalo Ridge')
# (17, 'Keating Cutoff')
# (17, 'Shirttail')
# (17, 'Jackson')
# (17, 'Keeney')
# (17, 'Pole Creek')
# (16, 'Rome Overlook')
# (16, 'RGFO - Four Mile')
# (16, 'D06_Ute Canyon')
# (16, 'Grass Mesa')
# (15, 'Lookout Mtn')
# (15, 'South Canyon')
# (15, 'Great Divide')
# (15, 'D10 - Flagstaff Mtn. - Cold')
# (15, 'D11_Guanella_Pass')
# (15, 'D11_Miller_Gulch')
# (15, 'Big Horn')
# (15, 'Blue Park')
# (15, 'Red Feather')
# (14, 'D02_Red_Deer')
# (14, 'D03_Gibson')
# (14, 'D03_Willis_Creek')
# (14, 'West Elk Creek')
# (14, 'D07_Cimarron River')
# (14, 'D07_Cimarron South')
# (14, 'Baker Park')
# (14, 'Prospect')
# (13, 'Hall Creek')
# (13, 'Sharpnose')
# (13, 'CNTX_Comal_TX')
# (13, 'CNTX_Hays_TX')
# (13, 'CNTX_McCl_TX')
# (13, 'HILL_Edwards2_TX')
# (13, 'HILL_Edwards_TX')
# (13, 'HILL_Gillespie_TX')
# (13, 'HILL_SanSaba_TX')
# (13, 'NETX_Wood_TX')
# (13, 'NOTX_Hood_TX')
# (13, 'NOTX_Palo_TX')
# (13, 'RGPL_Dimmit_TX')
# (13, 'ROPL_Taylor_TX')
# (13, 'SETX_Newt_TX')
# (13, 'SETX_SAug_TX')
# (13, 'SETX_Tylr_TX')
# (12, 'TPEC_Presidio_TX')
# (12, 'Big Thicket National Preserve')
# (12, 'Lake Hughes')
# (12, 'Mt. Baldy Village')
# (12, 'Hastings Old Growth')
# (12, 'Smith Ranch')
# (12, 'Mt. Woodson Station')
# (12, 'Lopez Lake')
# (12, 'Sonora')
# (12, 'Bitter Canyon, Castaic')
# (12, 'Clark Motorway, Malibu')
# (12, 'Glendora Ridge, Glendora')
# (12, 'Trippet Ranch, Topanga')
# (12, 'Gifford')
# (12, 'Los Alamos')
# (12, 'nacimiento')
# (12, 'Oak Flat')
# (12, 'ponderosa')
# (11, 'Reyes Creek')
# (11, 'Rose Valley')
# (11, 'San Marcos')
# (11, 'upper oso')
# (11, 'RMV')
# (11, 'Cottage')
# (11, 'Summit2')
# (11, 'Los Robles, Thousand Oaks')
# (11, 'Tapo Canyon, Simi Valley')
# (10, 'ASF Greer')
# (10, 'PNF Cherry')
# (9, 'PNF White Spar')
# (9, 'CAF Truchas 1')
# (9, 'CAF Truchas 2')
# (9, 'GNF Lincoln Canyon')
# (8, 'LNF Cosmic')
# (8, 'LNF Mayhill')
# (8, 'LNF Smokey Bear')
# (8, 'DUCK CREEK')
# (8, 'Lewis Canyon')
# (8, 'Lucky Springs')
# (8, 'McCoy Ridge')
# (8, 'New Jungo')
# (7, 'Palisade')
# (7, 'Panter')
# (7, 'RUTH')
# (7, 'Warm Springs')
# (5, 'Wells')

# %%
for i, j in zipdata.dtypes:
    print(i)
# Out:
# float64
# int64
# object
# float64
# int64
# int64
# int64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# int64
# int64
# int64
# float64
# float64
# float64
# float64
# int64
# int64
# int64
# float64
# float64
# float64
# float64
# int64
# int64
# int64
# float64
# float64
# float64
# float64
# float64

# %%
# percent = data['percent(t)'].to_numpy()
# del data['percent(t)']
del data['site']

# %%
d = data.to_numpy()

# %%
d.shape
# Out:
# (2615, 139)

# %%
train = data.loc[(data.date >= 2018)]

# %%
train
# Out:
#       slope(t)  elevation(t)  canopy_height(t)  forest_cover(t)  silt(t)  \
# 12    0.599961          1522                 0              130     36.0
# 13    0.599961          1522                 0              130     36.0
# 14    0.599961          1522                 0              130     36.0
# 15    0.599961          1522                 0              130     36.0
# 16    0.599961          1522                 0              130     36.0
# ...        ...           ...               ...              ...      ...
# 2603  0.979479          1479                 7              130     39.0
# 2604  0.979479          1479                 7              130     39.0
# 2605  0.979479          1479                 7              130     39.0
# 2606  0.979479          1479                 7              130     39.0
# 2607  0.979479          1479                 7              130     39.0
#
#       sand(t)  clay(t)    vv(t-3)    vh(t-3)  red(t-3)  ...  clay(t-2)  \
# 12       38.0     26.0 -13.755767 -22.731349  1409.500  ...       26.0
# 13       38.0     26.0 -12.071994 -21.032675  1294.000  ...       26.0
# 14       38.0     26.0 -14.369297 -22.781510  1491.250  ...       26.0
# 15       38.0     26.0 -12.733293 -20.986728  1578.625  ...       26.0
# 16       38.0     26.0 -15.480050 -23.213352  1666.000  ...       26.0
# ...       ...      ...        ...        ...       ...  ...        ...
# 2603     42.0     19.0 -13.070842 -21.172728  1556.750  ...       19.0
# 2604     42.0     19.0 -14.147845 -22.350978  1410.500  ...       19.0
# 2605     42.0     19.0 -14.043242 -22.002440  1495.250  ...       19.0
# 2606     42.0     19.0 -14.319087 -22.195318  1580.000  ...       19.0
# 2607     42.0     19.0 -14.697120 -22.231964  1587.500  ...       19.0
#
#       slope(t-1)  elevation(t-1)  canopy_height(t-1)  forest_cover(t-1)  \
# 12      0.599961            1522                   0                130
# 13      0.599961            1522                   0                130
# 14      0.599961            1522                   0                130
# 15      0.599961            1522                   0                130
# 16      0.599961            1522                   0                130
# ...          ...             ...                 ...                ...
# 2603    0.979479            1479                   7                130
# 2604    0.979479            1479                   7                130
# 2605    0.979479            1479                   7                130
# 2606    0.979479            1479                   7                130
# 2607    0.979479            1479                   7                130
#
#       silt(t-1)  sand(t-1)  clay(t-1)   latitude   longitude
# 12         36.0       38.0       26.0  42.441111 -115.885556
# 13         36.0       38.0       26.0  42.441111 -115.885556
# 14         36.0       38.0       26.0  42.441111 -115.885556
# 15         36.0       38.0       26.0  42.441111 -115.885556
# 16         36.0       38.0       26.0  42.441111 -115.885556
# ...         ...        ...        ...        ...         ...
# 2603       39.0       42.0       19.0  39.789167 -119.686389
# 2604       39.0       42.0       19.0  39.789167 -119.686389
# 2605       39.0       42.0       19.0  39.789167 -119.686389
# 2606       39.0       42.0       19.0  39.789167 -119.686389
# 2607       39.0       42.0       19.0  39.789167 -119.686389
#
# [835 rows x 138 columns]

# %%
train.drop(['date', 'percent(t)'], axis=1, inplace=True)
# Out:
# C:\Users\sharan\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
train = train.to_numpy()

# %%
train.shape
# Out:
# (835, 138)
